# %% [markdown]
# ![pandas](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/2880px-Pandas_logo.svg.png)

# %% [markdown]
# # Objectives

# %% [markdown]
# - Load .csv files into `pandas` DataFrames
# - Describe and manipulate data in Series and DataFrames

# %% [markdown]
# # What is Pandas?
#
# ![I have no idea what I'm doing panda](https://cdn-images-1.medium.com/max/1600/1*oBx032ncOwLmCFX3Epo3Zg.jpeg)
#
# Just kidding - not actual literal pandas.

# %% [markdown]
# Pandas, as [the Anaconda docs](https://docs.anaconda.com/anaconda/packages/py3.7_osx-64/) tell us, offers us "High-performance, easy-to-use data structures and data analysis tools." It's something like "Excel for Python", but it's quite a bit more powerful. The name comes from "panel data", a common way to describe the kind of multidimensional data we'll be working with in certain academic circles (namely, statistics and econometrics) [[Source]](https://www.dlr.de/sc/Portaldata/15/Resources/dokumente/pyhpc2011/submissions/pyhpc2011_submission_9.pdf)
#
# In order to use pandas, we'll need to import it into our notebook first.

# %%
# Import - using the common alias
import pandas as pd

# %% [markdown]
# ## Accessing Data
#
# ![pandas documentation image showcasing the kinds of data it can both read and write to](https://pandas.pydata.org/docs/_images/02_io_readwrite.svg)
#
# [[Image Source]](https://pandas.pydata.org/docs/getting_started/intro_tutorials/02_read_write.html)

# %% [markdown]
# Pandas can access a ton of different data types, including some that should be familiar: CSVs and JSONs! That's right, no more `with` / `open` statements now that we're using pandas!
#
# Most of the time, we'll see CSVs - so let's access a 'toy' data set quickly just to familiarize ourselves with using pandas. There's a heart dataset available in the data folder on this repository - let's read that in.

# %%
# Use read_csv to read in the heart csv file
# Need to assign it to a variable too - let's call this heart_df
heart_df = pd.read_csv('data/heart.csv')

# %% [markdown]
# Find out more about this dataset [here](https://archive.ics.uci.edu/ml/datasets/Statlog+%28Heart%29).

# %% [markdown]
# The output of the `.read_csv()` function is a pandas *DataFrame*, which has a familiar tabaular structure of rows and columns.

# %%
# Let's check this variable out
heart_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# What type is this variable?
type(heart_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## DataFrames and Series

# %% [markdown]
# Two main types of pandas objects are the DataFrame and the Series, the latter being in effect a single column of the former:

# %%
# Let's grab just one column
age_series = heart_df['age']

# %%
age_series
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %% [markdown]
# Notice how we can isolate a column of our DataFrame simply by using square brackets together with the name of the column. We can also access columns as an attribute of the DataFrame - but that only works if the name of the column doesn't have any spaces or weird characters!

# %%
heart_df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
# What type is the column?
type(age_series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Both Series and DataFrames have an *index* as well:

# %%
heart_df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
age_series.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %% [markdown]
# DataFrames have columns - but a Series is just a single column, so it doesn't have the columns attribute.

# %%
heart_df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_df.keys()
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
age_series.columns
# This will throw an error!
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-38187cf7a6e7> in <module>
# ----> 1 age_series.columns
#       2 # This will throw an error!
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %% [markdown]
# Pandas is built on top of NumPy, and we can always access the NumPy array underlying a DataFrame using `.values`.

# %%
heart_df.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %% [markdown]
# ## Basic DataFrame Attributes and Methods

# %% [markdown]
# ### `.head()` : first 5 rows

# %%
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
first_five = heart_df.head()

# %%
first_five
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### `.tail()` : last 5 rows

# %%
heart_df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
heart_df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %% [markdown]
# ### `.info()` : information about the columns, including about nulls in those columns

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ### `.describe()` : statistics about the data

# %%
heart_df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# ### `.dtypes` : data types of each column

# %%
heart_df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ### `.shape` : number of rows and columns

# %%
heart_df.shape
# Out:
# (303, 14)

# %% [markdown]
# ### Statistics
#
# We saw them above, in the `.describe`, but we can also calculate statistics by calling them individually.

# %%
# Calculate the mean - for the whole dataframe!
heart_df.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
# Now min
heart_df.min()
# Out:
# age          29.0
# sex           0.0
# cp            0.0
# trestbps     94.0
# chol        126.0
# fbs           0.0
# restecg       0.0
# thalach      71.0
# exang         0.0
# oldpeak       0.0
# slope         0.0
# ca            0.0
# thal          0.0
# target        0.0
# dtype: float64

# %%
# And max
heart_df['age'].min()
# Out:
# 29

# %% [markdown]
# ## Enough With The Small Stuff - Bring On Real Data!
#
# Let's access an open data portal and get some real live data!

# %% [markdown]
# Austin Animal Center Intake Data: https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm/

# %%
# Accessing a CSV from a url
intakes_url = pd.read_csv('https://data.austintexas.gov/resource/wter-evkm.csv')
intakes_url.head()
# Out:
#   animal_id       name                 datetime                datetime2  \
# 0   A875253        NaN  2023-02-24T09:33:00.000  2023-02-24T09:33:00.000
# 1   A839506       Beau  2023-02-24T08:18:00.000  2023-02-24T08:18:00.000
# 2   A875242  Butterfly  2023-02-24T08:14:00.000  2023-02-24T08:14:00.000
# 3   A875239    A875239  2023-02-24T08:03:00.000  2023-02-24T08:03:00.000
# 4   A839495      Sammy  2023-02-24T00:43:00.000  2023-02-24T00:43:00.000
#
#                           found_location    intake_type intake_condition  \
# 0    5300 Sh 71 Eastbound in Travis (TX)          Stray          Injured
# 1  13705 Fuchs Grove Road in Travis (TX)          Stray          Injured
# 2         6816 Boyce Lane in Travis (TX)  Public Assist           Normal
# 3     4434 Frontier Trail in Austin (TX)          Stray             Sick
# 4    13705 Fuchs Grove Rd in Travis (TX)  Public Assist          Injured
#
#   animal_type sex_upon_intake age_upon_intake                      breed  \
# 0         Dog         Unknown         2 years  Chow Chow/German Shepherd
# 1         Dog   Neutered Male         8 years           Bull Terrier Mix
# 2         Dog   Intact Female          1 year   Jack Russell Terrier Mix
# 3         Dog     Intact Male         2 years        German Shepherd Mix
# 4         Dog   Neutered Male         3 years               Pit Bull Mix
#
#          color
# 0  Black/Black
# 1   Gray/White
# 2  White/Black
# 3    Tan/White
# 4   Gray/White

# %%
# Same as the JSON output from this API endpoint, but different levels of detail for dates!
pd.read_json('https://data.austintexas.gov/resource/wter-evkm.json').head()
# Out:
#   animal_id            datetime                datetime2  \
# 0   A875253 2023-02-24 09:33:00  2023-02-24T09:33:00.000
# 1   A839506 2023-02-24 08:18:00  2023-02-24T08:18:00.000
# 2   A875242 2023-02-24 08:14:00  2023-02-24T08:14:00.000
# 3   A875239 2023-02-24 08:03:00  2023-02-24T08:03:00.000
# 4   A839495 2023-02-24 00:43:00  2023-02-24T00:43:00.000
#
#                           found_location    intake_type intake_condition  \
# 0    5300 Sh 71 Eastbound in Travis (TX)          Stray          Injured
# 1  13705 Fuchs Grove Road in Travis (TX)          Stray          Injured
# 2         6816 Boyce Lane in Travis (TX)  Public Assist           Normal
# 3     4434 Frontier Trail in Austin (TX)          Stray             Sick
# 4    13705 Fuchs Grove Rd in Travis (TX)  Public Assist          Injured
#
#   animal_type sex_upon_intake age_upon_intake                      breed  \
# 0         Dog         Unknown         2 years  Chow Chow/German Shepherd
# 1         Dog   Neutered Male         8 years           Bull Terrier Mix
# 2         Dog   Intact Female          1 year   Jack Russell Terrier Mix
# 3         Dog     Intact Male         2 years        German Shepherd Mix
# 4         Dog   Neutered Male         3 years               Pit Bull Mix
#
#          color       name
# 0  Black/Black        NaN
# 1   Gray/White       Beau
# 2  White/Black  Butterfly
# 3    Tan/White    A875239
# 4   Gray/White      Sammy

# %%
# But this is only 1000 rows... website says there's 136K rows!
intakes_url.shape
# Out:
# (1000, 12)

# %%
# It's a limitation of the API - let's just download the data instead
# It's in the data folder
df = pd.read_csv('data/Austin_Animal_Center_Intakes_022822.csv')

# %%
# Now let's explore those earlier attributes and methods on this dataset!
# Check the first 5 rows
df.head()
# Out:
#   Animal ID     Name                DateTime     MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM     July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM    April 2016
# 3   A665644      NaN  10/21/2013 07:59:00 AM  October 2013
# 4   A682524      Rio  06/29/2014 10:38:00 AM     June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
# Check the last 5 rows
df.tail(3)
# Out:
#        Animal ID   Name                DateTime      MonthYear  \
# 136760   A851977  *Jack  02/22/2022 01:34:00 PM  February 2022
# 136761   A852127  Sonic  02/25/2022 01:05:00 PM  February 2022
# 136762   A852194  Queen  02/27/2022 01:44:00 PM  February 2022
#
#                                 Found Location Intake Type Intake Condition  \
# 136760    1200 Montopolis Drive in Austin (TX)       Stray           Normal
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)       Stray           Normal
# 136762        8071 N Lamar Blvd in Austin (TX)       Stray           Normal
#
#        Animal Type Sex upon Intake Age upon Intake  \
# 136760         Dog     Intact Male         2 years
# 136761         Dog     Intact Male         2 years
# 136762         Dog   Intact Female        4 months
#
#                                 Breed         Color
# 136760  Chihuahua Shorthair/Dachshund   Black/White
# 136761                   Pit Bull Mix  White/Yellow
# 136762                     Cane Corso    Blue Cream

# %%
# Check the shape
df.shape
# Out:
# (136763, 12)

# %%
# Check the datatypes
df.dtypes
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# MonthYear           object
# Found Location      object
# Intake Type         object
# Intake Condition    object
# Animal Type         object
# Sex upon Intake     object
# Age upon Intake     object
# Breed               object
# Color               object
# dtype: object

# %%
# Check more general information on the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136763 entries, 0 to 136762
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         136763 non-null  object
#  1   Name              95772 non-null   object
#  2   DateTime          136763 non-null  object
#  3   MonthYear         136763 non-null  object
#  4   Found Location    136763 non-null  object
#  5   Intake Type       136763 non-null  object
#  6   Intake Condition  136763 non-null  object
#  7   Animal Type       136763 non-null  object
#  8   Sex upon Intake   136762 non-null  object
#  9   Age upon Intake   136763 non-null  object
#  10  Breed             136763 non-null  object
#  11  Color             136763 non-null  object
# dtypes: object(12)
# memory usage: 12.5+ MB

# %%
# Check summary/descriptive statistics on the dataframe
df.describe(include=[object])
# Out:
#        Animal ID   Name                DateTime  MonthYear Found Location  \
# count     136763  95772                  136763     136763         136763
# unique    122244  23058                   96160        101          57763
# top      A721033    Max  09/23/2016 12:00:00 PM  June 2015    Austin (TX)
# freq          33    620                      64       2189          25674
#
#        Intake Type Intake Condition Animal Type Sex upon Intake  \
# count       136763           136763      136763          136762
# unique           6               15           5               5
# top          Stray           Normal         Dog     Intact Male
# freq         94180           117867       77098           44962
#
#        Age upon Intake                   Breed        Color
# count           136763                  136763       136763
# unique              53                    2734          614
# top             1 year  Domestic Shorthair Mix  Black/White
# freq             23422                   32034        14291

# %% [markdown]
# #### Any Observations?
#
# - Just shows the 'Year' column - it's the only numeric column!

# %% [markdown]
# #### Any Observations?
#
# - Can see non-null counts, number of uniques, plus the most frequent and how frequent it is
# - Showcases the different kind of useful data you can explore when it's object vs numeric columns

# %% [markdown]
# ## Adding to a DataFrame

# %% [markdown]
# ### Adding Rows

# %% [markdown]
# We have a new animal coming in, captured here in a Python dictionary:

# %%
# Dictionary, where keys match the column names and values are the row values
# Note that the values are list-like - you could easily add more rows by adding to the lists!
next_row = {
    'Animal ID': ['A851755'],
    'Name': ["T'Challa"],
    'DateTime': ['2/28/2022 11:25:00 AM'],
    'MonthYear': ['2022'],
    'Found Location': ['Houston (TX)'],
    'Intake Type': ['Public Assist'],
    'Intake Condition': ['Normal'],
    'Animal Type': ['Cat'],
    'Sex upon Intake': ['Neutered Male'],
    'Age upon Intake': ['4 years'],
    'Breed': ['Domestic Shorthair'],
    'Color': ['Black']
}
next_row
# Out:
# {'Animal ID': ['A851755'],
#  'Name': ["T'Challa"],
#  'DateTime': ['2/28/2022 11:25:00 AM'],
#  'MonthYear': ['2022'],
#  'Found Location': ['Houston (TX)'],
#  'Intake Type': ['Public Assist'],
#  'Intake Condition': ['Normal'],
#  'Animal Type': ['Cat'],
#  'Sex upon Intake': ['Neutered Male'],
#  'Age upon Intake': ['4 years'],
#  'Breed': ['Domestic Shorthair'],
#  'Color': ['Black']}

# %% [markdown]
# How can we add this to the bottom of our dataset?

# %%
# Let's first turn this into a DataFrame.
# We can use the .from_dict() method.
new2 = pd.DataFrame(next_row)
new2
# Out:
#   Animal ID      Name               DateTime MonthYear Found Location  \
# 0   A851755  T'Challa  2/28/2022 11:25:00 AM      2022   Houston (TX)
#
#      Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0  Public Assist           Normal         Cat   Neutered Male         4 years
#
#                 Breed  Color
# 0  Domestic Shorthair  Black

# %%
# Now we just need to concatenate the two DataFrames together.
# Note the `ignore_index` parameter! We'll set that to True.

df_augmented = pd.concat([df, new2], ignore_index=True)

# %%
# Let's check the end to make sure we were successful!
df_augmented.tail()
# Out:
#        Animal ID      Name                DateTime      MonthYear  \
# 136759   A852221      Coco  02/28/2022 11:05:00 AM  February 2022
# 136760   A851977     *Jack  02/22/2022 01:34:00 PM  February 2022
# 136761   A852127     Sonic  02/25/2022 01:05:00 PM  February 2022
# 136762   A852194     Queen  02/27/2022 01:44:00 PM  February 2022
# 136763   A851755  T'Challa   2/28/2022 11:25:00 AM           2022
#
#                                 Found Location    Intake Type  \
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                 Breed         Color
# 136759                 Great Pyrenees         White
# 136760  Chihuahua Shorthair/Dachshund   Black/White
# 136761                   Pit Bull Mix  White/Yellow
# 136762                     Cane Corso    Blue Cream
# 136763             Domestic Shorthair         Black

# %% [markdown]
# ### Adding (and Deleting) Columns

# %% [markdown]
# Adding a column is very easy in `pandas`. Let's add a new column to our dataset called "test", and set all of its values to 0.

# %%
# Create a new column, 'test', where every value in the col is 0
df_augmented['test'] = 0

# %%
# Sanity check
df_augmented.head()
# Out:
#   Animal ID     Name                DateTime     MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM     July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM    April 2016
# 3   A665644      NaN  10/21/2013 07:59:00 AM  October 2013
# 4   A682524      Rio  06/29/2014 10:38:00 AM     June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color  test
# 0                             Beagle Mix     Tricolor     0
# 1               English Springer Spaniel  White/Liver     0
# 2                            Basenji Mix  Sable/White     0
# 3                 Domestic Shorthair Mix       Calico     0
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray     0

# %% [markdown]
# But we don't need that - let's drop that column.

# %%
# Drop that test column
df_augmented.drop(columns=['test'])
# Out:
#        Animal ID      Name                DateTime      MonthYear  \
# 0        A786884    *Brock  01/03/2019 04:19:00 PM   January 2019
# 1        A706918     Belle  07/05/2015 12:59:00 PM      July 2015
# 2        A724273   Runster  04/14/2016 06:43:00 PM     April 2016
# 3        A665644       NaN  10/21/2013 07:59:00 AM   October 2013
# 4        A682524       Rio  06/29/2014 10:38:00 AM      June 2014
# ...          ...       ...                     ...            ...
# 136759   A852221      Coco  02/28/2022 11:05:00 AM  February 2022
# 136760   A851977     *Jack  02/22/2022 01:34:00 PM  February 2022
# 136761   A852127     Sonic  02/25/2022 01:05:00 PM  February 2022
# 136762   A852194     Queen  02/27/2022 01:44:00 PM  February 2022
# 136763   A851755  T'Challa   2/28/2022 11:25:00 AM           2022
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color
# 0                                  Beagle Mix      Tricolor
# 1                    English Springer Spaniel   White/Liver
# 2                                 Basenji Mix   Sable/White
# 3                      Domestic Shorthair Mix        Calico
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray
# ...                                       ...           ...
# 136759                         Great Pyrenees         White
# 136760          Chihuahua Shorthair/Dachshund   Black/White
# 136761                           Pit Bull Mix  White/Yellow
# 136762                             Cane Corso    Blue Cream
# 136763                     Domestic Shorthair         Black
#
# [136764 rows x 12 columns]

# %%
# Alternate way using axis arguement
df_augmented.drop('test', axis=1).head()
# Out:
#   Animal ID     Name                DateTime     MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM     July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM    April 2016
# 3   A665644      NaN  10/21/2013 07:59:00 AM  October 2013
# 4   A682524      Rio  06/29/2014 10:38:00 AM     June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
# Sanity check
df_augmented.head()
# Out:
#   Animal ID     Name                DateTime     MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM     July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM    April 2016
# 3   A665644      NaN  10/21/2013 07:59:00 AM  October 2013
# 4   A682524      Rio  06/29/2014 10:38:00 AM     June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color  test
# 0                             Beagle Mix     Tricolor     0
# 1               English Springer Spaniel  White/Liver     0
# 2                            Basenji Mix  Sable/White     0
# 3                 Domestic Shorthair Mix       Calico     0
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray     0

# %%
# Save over
#df_augmented = df_augmented.drop('test', axis=1)

# In place
df_augmented.drop('test', axis=1, inplace=True)
df_augmented.head()
# Out:
#   Animal ID     Name                DateTime     MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM     July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM    April 2016
# 3   A665644      NaN  10/21/2013 07:59:00 AM  October 2013
# 4   A682524      Rio  06/29/2014 10:38:00 AM     June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %% [markdown]
# We can also do math with columns, or use mathematical notation to combine columns even when they aren't numerical!
#
# We don't have any numeric data in this current dataset. But we can still create a combined "Type" column that combines the values of our Intake Type and Animal Type columns.

# %%
# Create a new column, 'Type', from the two 'Type' columns
df_augmented['Type'] = df_augmented['Intake Type'] + " " + df_augmented['Animal Type']

# %%
# Sanity check
df_augmented.head()
# Out:
#   Animal ID     Name                DateTime     MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM     July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM    April 2016
# 3   A665644      NaN  10/21/2013 07:59:00 AM  October 2013
# 4   A682524      Rio  06/29/2014 10:38:00 AM     June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color       Type
# 0                             Beagle Mix     Tricolor  Stray Dog
# 1               English Springer Spaniel  White/Liver  Stray Dog
# 2                            Basenji Mix  Sable/White  Stray Dog
# 3                 Domestic Shorthair Mix       Calico  Stray Cat
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray  Stray Dog

# %% [markdown]
# ## Filtering

# %% [markdown]
# We can use filtering techniques to see only certain rows of our data. Let's look at only animals taken into the center during or after 2020:

# %%
# Check which rows have an intake year greater than or equal to 2020
df_augmented['Animal Type'] == 'Cat'
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 136759    False
# 136760    False
# 136761    False
# 136762    False
# 136763     True
# Name: Animal Type, Length: 136764, dtype: bool

# %%
# Let's explore an interesting property of boolean columns...
# Find out the total sum of animals taken in during or after 2020
sum(df_augmented['Animal Type'] == 'Cat')
# Out:
# 51753

# %% [markdown]
# But this only gives us True/False outputs... what if we want to really filter?

# %% [markdown]
# ### `.loc`

# %% [markdown]
# We can locate and segment down to only rows where some condition is true using `.loc`. This takes in a condition, and only outputs the rows where that condition is True!
#
# > **Note:** locate (`.loc`) uses square brackets, not parentheses! Often, square brackets denote location-focused actions, like this one.
#
# Let's try this first with the condition we just built, and locate all animals taken in during or after 2020.

# %%
# Create a subset dataframe of animals taken in during or after 2020
subset_cat = df_augmented.loc[df_augmented['Animal Type'] == 'Cat']

# %%
subset_cat.head()
# Out:
#    Animal ID    Name                DateTime     MonthYear  \
# 3    A665644     NaN  10/21/2013 07:59:00 AM  October 2013
# 7    A844350   *Ella  10/15/2021 11:40:00 AM  October 2021
# 9    A818975     NaN  06/18/2020 02:53:00 PM     June 2020
# 10   A774147     NaN  06/11/2018 07:45:00 AM     June 2018
# 11   A731435  *Casey  08/08/2016 05:52:00 PM   August 2016
#
#                                    Found Location      Intake Type  \
# 3                                     Austin (TX)            Stray
# 7   2112 East William Cannon Drive in Austin (TX)            Stray
# 9           Braker Lane And Metric in Travis (TX)            Stray
# 10                  6600 Elm Creek in Austin (TX)            Stray
# 11                                    Austin (TX)  Owner Surrender
#
#    Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 3              Sick         Cat   Intact Female         4 weeks
# 7            Normal         Cat   Intact Female        6 months
# 9            Normal         Cat     Intact Male         4 weeks
# 10          Injured         Cat   Intact Female         4 weeks
# 11           Normal         Cat   Neutered Male        5 months
#
#                      Breed        Color                 Type
# 3   Domestic Shorthair Mix       Calico            Stray Cat
# 7       Domestic Shorthair  Brown Tabby            Stray Cat
# 9       Domestic Shorthair  Cream Tabby            Stray Cat
# 10  Domestic Shorthair Mix  Black/White            Stray Cat
# 11  Domestic Shorthair Mix  Cream Tabby  Owner Surrender Cat

# %% [markdown]
# We can return only certain columns when we do this, by adding an argument after the condition:

# %%
# Let's return just the 'Animal ID', 'DateTime' and 'Type' columns
subset_cat2 = df_augmented.loc[df_augmented['Animal Type'] == 'Cat', ['Animal ID', 'Intake Type', 'Color']]
subset_cat2
# Out:
#        Animal ID      Intake Type        Color
# 3        A665644            Stray       Calico
# 7        A844350            Stray  Brown Tabby
# 9        A818975            Stray  Cream Tabby
# 10       A774147            Stray  Black/White
# 11       A731435  Owner Surrender  Cream Tabby
# ...          ...              ...          ...
# 136754   A852234            Stray       Calico
# 136755   A852228  Owner Surrender  Brown Tabby
# 136756   A852227  Owner Surrender        Black
# 136757   A852216            Stray  Black/White
# 136763   A851755    Public Assist        Black
#
# [51753 rows x 3 columns]

# %% [markdown]
# What if I want to segment using multiple conditions? Use `&` for "and" and `|` for "or" - and use parentheses around individual conditions!

# %%
# Find all the Stray Cats taken in during or after 2020
df_augmented.loc[(df_augmented['Animal Type'] == 'Cat') & (df_augmented['Color'] == 'Black')]
# Out:
#        Animal ID          Name                DateTime      MonthYear  \
# 35       A696205           Roo  02/12/2015 11:57:00 AM  February 2015
# 39       A706507           NaN  06/29/2015 05:04:00 PM      June 2015
# 41       A789526        Sixlet  02/23/2019 11:22:00 AM  February 2019
# 43       A727838           NaN  05/26/2016 02:01:00 PM       May 2016
# 56       A736501        Travis  10/11/2016 04:43:00 PM   October 2016
# ...          ...           ...                     ...            ...
# 136732   A852023  *Rain Shadow  02/23/2022 12:15:00 PM  February 2022
# 136733   A852038       *Minkus  02/23/2022 03:01:00 PM  February 2022
# 136748   A852225          Lucy  02/28/2022 12:13:00 PM  February 2022
# 136756   A852227       Georgia  02/28/2022 12:13:00 PM  February 2022
# 136763   A851755      T'Challa   2/28/2022 11:25:00 AM           2022
#
#                              Found Location      Intake Type Intake Condition  \
# 35                              Austin (TX)  Owner Surrender           Normal
# 39          5306  Peppertree in Austin (TX)            Stray           Normal
# 41      2504 Stratford Drive in Austin (TX)            Stray           Normal
# 43          2504 Huntwick Dr in Austin (TX)            Stray           Normal
# 56                              Austin (TX)  Owner Surrender             Sick
# ...                                     ...              ...              ...
# 136732      6600 Antigo Lane in Austin (TX)            Stray           Normal
# 136733         3403 E 5Th St in Austin (TX)            Stray          Injured
# 136748                          Travis (TX)  Owner Surrender           Normal
# 136756                          Travis (TX)  Owner Surrender           Normal
# 136763                         Houston (TX)    Public Assist           Normal
#
#        Animal Type Sex upon Intake Age upon Intake                   Breed  \
# 35             Cat   Spayed Female         2 years  Domestic Shorthair Mix
# 39             Cat         Unknown          4 days  Domestic Shorthair Mix
# 41             Cat   Intact Female         1 month  Domestic Shorthair Mix
# 43             Cat   Intact Female         2 years  Domestic Shorthair Mix
# 56             Cat   Neutered Male        15 years  Domestic Shorthair Mix
# ...            ...             ...             ...                     ...
# 136732         Cat         Unknown        4 months      Domestic Shorthair
# 136733         Cat   Neutered Male       11 months      Domestic Shorthair
# 136748         Cat   Intact Female        3 months  Domestic Shorthair Mix
# 136756         Cat   Intact Female        3 months  Domestic Shorthair Mix
# 136763         Cat   Neutered Male         4 years      Domestic Shorthair
#
#         Color                 Type
# 35      Black  Owner Surrender Cat
# 39      Black            Stray Cat
# 41      Black            Stray Cat
# 43      Black            Stray Cat
# 56      Black  Owner Surrender Cat
# ...       ...                  ...
# 136732  Black            Stray Cat
# 136733  Black            Stray Cat
# 136748  Black  Owner Surrender Cat
# 136756  Black  Owner Surrender Cat
# 136763  Black    Public Assist Cat
#
# [6796 rows x 13 columns]

# %% [markdown]
# ## Your turn!

# %% [markdown]
# ### Exercise 1
#
# You need to find dogs that need extra attention - How would you find all dogs where the intake condition is NOT normal?

# %%
# Your code here

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#
# ```python
# df_augmented.loc[(df_augmented['Animal Type'] == 'Dog') & (df_augmented['Intake Condition'] != 'Normal')]
# ```
# </details>

# %% [markdown]
# ### Exercise 2
#
# You need to find animals that might need to be fixed - How would you find all animals that are either Intact Male or Intact Female?

# %%
# Your code here

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#
# ```python
# df_augmented[(df_augmented['Sex upon Intake'] == 'Intact Male') |
#              (df_augmented['Sex upon Intake'] == 'Intact Female')]
# ```
# </details>

# %% [markdown]
# ### `.iloc`

# %% [markdown]
# `.iloc` is used for integer-location based indexing, aka locate by number. It can take in lists of numbers, python slices, or specific numbers - but sometimes it can be a bit tricky!

# %%
# Find the first 3 rows
df_augmented.iloc[0:3]
# Out:
#   Animal ID     Name                DateTime     MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM     July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM    April 2016
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake                     Breed  \
# 0         Dog   Neutered Male         2 years                Beagle Mix
# 1         Dog   Spayed Female         8 years  English Springer Spaniel
# 2         Dog     Intact Male       11 months               Basenji Mix
#
#          Color       Type
# 0     Tricolor  Stray Dog
# 1  White/Liver  Stray Dog
# 2  Sable/White  Stray Dog

# %%
# Same as using head(3)
df_augmented.head()
# Out:
#   Animal ID     Name                DateTime     MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM     July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM    April 2016
# 3   A665644      NaN  10/21/2013 07:59:00 AM  October 2013
# 4   A682524      Rio  06/29/2014 10:38:00 AM     June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color       Type
# 0                             Beagle Mix     Tricolor  Stray Dog
# 1               English Springer Spaniel  White/Liver  Stray Dog
# 2                            Basenji Mix  Sable/White  Stray Dog
# 3                 Domestic Shorthair Mix       Calico  Stray Cat
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray  Stray Dog

# %%
# Can look exactly where the 0 index is
df_augmented.iloc[0]
# Out:
# Animal ID                                       A786884
# Name                                             *Brock
# DateTime                         01/03/2019 04:19:00 PM
# MonthYear                                  January 2019
# Found Location      2501 Magin Meadow Dr in Austin (TX)
# Intake Type                                       Stray
# Intake Condition                                 Normal
# Animal Type                                         Dog
# Sex upon Intake                           Neutered Male
# Age upon Intake                                 2 years
# Breed                                        Beagle Mix
# Color                                          Tricolor
# Type                                          Stray Dog
# Name: 0, dtype: object

# %%
# But what about our subset dataframe above? It doesn't have an index 0
subset_cat.head()
# Out:
#    Animal ID    Name                DateTime     MonthYear  \
# 3    A665644     NaN  10/21/2013 07:59:00 AM  October 2013
# 7    A844350   *Ella  10/15/2021 11:40:00 AM  October 2021
# 9    A818975     NaN  06/18/2020 02:53:00 PM     June 2020
# 10   A774147     NaN  06/11/2018 07:45:00 AM     June 2018
# 11   A731435  *Casey  08/08/2016 05:52:00 PM   August 2016
#
#                                    Found Location      Intake Type  \
# 3                                     Austin (TX)            Stray
# 7   2112 East William Cannon Drive in Austin (TX)            Stray
# 9           Braker Lane And Metric in Travis (TX)            Stray
# 10                  6600 Elm Creek in Austin (TX)            Stray
# 11                                    Austin (TX)  Owner Surrender
#
#    Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 3              Sick         Cat   Intact Female         4 weeks
# 7            Normal         Cat   Intact Female        6 months
# 9            Normal         Cat     Intact Male         4 weeks
# 10          Injured         Cat   Intact Female         4 weeks
# 11           Normal         Cat   Neutered Male        5 months
#
#                      Breed        Color                 Type
# 3   Domestic Shorthair Mix       Calico            Stray Cat
# 7       Domestic Shorthair  Brown Tabby            Stray Cat
# 9       Domestic Shorthair  Cream Tabby            Stray Cat
# 10  Domestic Shorthair Mix  Black/White            Stray Cat
# 11  Domestic Shorthair Mix  Cream Tabby  Owner Surrender Cat

# %%
# Try it...
subset_cat.iloc[-1]
# Out:
# Animal ID                         A851755
# Name                             T'Challa
# DateTime            2/28/2022 11:25:00 AM
# MonthYear                            2022
# Found Location               Houston (TX)
# Intake Type                 Public Assist
# Intake Condition                   Normal
# Animal Type                           Cat
# Sex upon Intake             Neutered Male
# Age upon Intake                   4 years
# Breed                  Domestic Shorthair
# Color                               Black
# Type                    Public Assist Cat
# Name: 136763, dtype: object

# %%
df_augmented.loc[]
# Out:
# Animal ID                                       A786884
# Name                                             *Brock
# DateTime                         01/03/2019 04:19:00 PM
# MonthYear                                  January 2019
# Found Location      2501 Magin Meadow Dr in Austin (TX)
# Intake Type                                       Stray
# Intake Condition                                 Normal
# Animal Type                                         Dog
# Sex upon Intake                           Neutered Male
# Age upon Intake                                 2 years
# Breed                                        Beagle Mix
# Color                                          Tricolor
# Type                                          Stray Dog
# Name: 0, dtype: object

# %% [markdown]
# ## Series Methods

# %% [markdown]
# ### `.value_counts()`

# %% [markdown]
# How many different values does the Animal Type column have? What about Breed?

# %%
# Check the value counts for Animal Type
df_augmented['Animal Type'].value_counts()
# Out:
# Dog          77098
# Cat          51753
# Other         7253
# Bird           636
# Livestock       24
# Name: Animal Type, dtype: int64

# %%
# Now check Breed
df_augmented['Breed'].value_counts()
# Out:
# Domestic Shorthair Mix                    32034
# Domestic Shorthair                        10441
# Pit Bull Mix                               8913
# Labrador Retriever Mix                     7370
# Chihuahua Shorthair Mix                    6486
#                                           ...
# Bruss Griffon/Maltese                         1
# Belgian Hare                                  1
# Vulture                                       1
# Toy Fox Terrier/Yorkshire Terrier             1
# Standard Schnauzer/Australian Shepherd        1
# Name: Breed, Length: 2734, dtype: int64

# %% [markdown]
# Sometimes, this is more useful than others... but, can check the percentage of the total, which might be more useful!

# %%
# Use the normalize argument to change how the count is displayed
df_augmented['Animal Type'].value_counts(normalize=True, ascending=True)
# Out:
# Livestock    0.000175
# Bird         0.004650
# Other        0.053033
# Cat          0.378411
# Dog          0.563730
# Name: Animal Type, dtype: float64

# %% [markdown]
# ### `.sort_values()`
#
# As you can imagine, this works differently whether you're using it on a numeric or non-numeric column

# %%
# Let's sort the year column

# %%
# Now, sort the Animal Type col
df_augmented['Animal Type'].sort_values()
# Out:
# 4867       Bird
# 96361      Bird
# 15477      Bird
# 3791       Bird
# 34239      Bird
#           ...
# 59440     Other
# 106179    Other
# 15456     Other
# 46896     Other
# 37968     Other
# Name: Animal Type, Length: 136764, dtype: object

# %%
# We can do this on the whole dataframe, it just needs to know what to sort by
# We can always choose ascending or descending
sorted_df = df_augmented.sort_values(by='Animal Type')
sorted_df
# Out:
#        Animal ID          Name                DateTime       MonthYear  \
# 4867     A720744    Rooster 28  02/14/2016 04:02:00 PM   February 2016
# 96361    A720751  Rooster  D 5  02/14/2016 04:02:00 PM   February 2016
# 15477    A683716           NaN  07/14/2014 01:54:00 PM       July 2014
# 3791     A818041           NaN  05/31/2020 06:33:00 PM        May 2020
# 34239    A787492           NaN  01/14/2019 01:00:00 PM    January 2019
# ...          ...           ...                     ...             ...
# 59440    A829431           NaN  02/10/2021 03:49:00 PM   February 2021
# 106179   A745754           NaN  03/23/2017 01:19:00 PM      March 2017
# 15456    A816009           NaN  04/02/2020 04:52:00 PM      April 2020
# 46896    A758611           NaN  09/19/2017 12:38:00 PM  September 2017
# 37968    A766167        Sophie  02/03/2018 01:36:00 PM   February 2018
#
#                                       Found Location      Intake Type  \
# 4867             21413 Webber Oaks Cv in Travis (TX)    Public Assist
# 96361            21413 Webber Oaks Cv in Travis (TX)    Public Assist
# 15477   9401 Capital Of Texas Highway in Austin (TX)            Stray
# 3791                 1103 E Applegate in Austin (TX)            Stray
# 34239                9505 Cheryl Lynn in Austin (TX)         Wildlife
# ...                                              ...              ...
# 59440           905 Rocking Spur Cove in Travis (TX)            Stray
# 106179             2222 Rio Grande St in Austin (TX)         Wildlife
# 15456             5310 Joe Sayers Ave in Austin (TX)         Wildlife
# 46896              9300 Roxanna Drive in Austin (TX)            Stray
# 37968                                    Austin (TX)  Owner Surrender
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 4867             Normal        Bird     Intact Male          1 year
# 96361            Normal        Bird     Intact Male          1 year
# 15477            Normal        Bird   Intact Female         1 month
# 3791             Normal        Bird     Intact Male          1 year
# 34239           Injured        Bird         Unknown         2 years
# ...                 ...         ...             ...             ...
# 59440            Normal       Other     Intact Male          1 year
# 106179           Normal       Other         Unknown          1 year
# 15456              Sick       Other         Unknown         2 years
# 46896            Normal       Other         Unknown          1 year
# 37968            Normal       Other   Intact Female        5 months
#
#                   Breed         Color                   Type
# 4867        Chicken Mix     Black/Red     Public Assist Bird
# 96361       Chicken Mix         White     Public Assist Bird
# 15477           Chicken  Brown/Yellow             Stray Bird
# 3791            Chicken     White/Red             Stray Bird
# 34239       Vulture Mix         Black          Wildlife Bird
# ...                 ...           ...                    ...
# 59440         Rabbit Sh         Black            Stray Other
# 106179              Bat         Black         Wildlife Other
# 15456               Bat         Brown         Wildlife Other
# 46896         Snake Mix   Black/Brown            Stray Other
# 37968   Californian Mix   White/Black  Owner Surrender Other
#
# [136764 rows x 13 columns]

# %%
next_row2 = {
    'Animal ID': ['A851755'],
    'Name': ["T'Challa"],
    'DateTime': ['2/28/2022 11:25:00 AM'],
    'MonthYear': ['2022'],
    'Found Location': ['Houston (TX)'],
    'Intake Type': ['Public Assist'],
    'Intake Condition': ['Normal'],
    'Animal Type': ['cat'],
    'Sex upon Intake': ['Neutered Male'],
    'Age upon Intake': ['4 years'],
    'Breed': ['Domestic Shorthair'],
    'Color': ['Black']
}
next_row2
# Out:
# {'Animal ID': ['A851755'],
#  'Name': ["T'Challa"],
#  'DateTime': ['2/28/2022 11:25:00 AM'],
#  'MonthYear': ['2022'],
#  'Found Location': ['Houston (TX)'],
#  'Intake Type': ['Public Assist'],
#  'Intake Condition': ['Normal'],
#  'Animal Type': ['cat'],
#  'Sex upon Intake': ['Neutered Male'],
#  'Age upon Intake': ['4 years'],
#  'Breed': ['Domestic Shorthair'],
#  'Color': ['Black']}

# %%
df_next = pd.DataFrame(next_row2)
df_next
# Out:
#   Animal ID      Name               DateTime MonthYear Found Location  \
# 0   A851755  T'Challa  2/28/2022 11:25:00 AM      2022   Houston (TX)
#
#      Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0  Public Assist           Normal         cat   Neutered Male         4 years
#
#                 Breed  Color
# 0  Domestic Shorthair  Black

# %%
df_new = pd.concat([df_augmented, df_next], ignore_index=True)
df_new.tail()
# Out:
#        Animal ID      Name                DateTime      MonthYear  \
# 136760   A851977     *Jack  02/22/2022 01:34:00 PM  February 2022
# 136761   A852127     Sonic  02/25/2022 01:05:00 PM  February 2022
# 136762   A852194     Queen  02/27/2022 01:44:00 PM  February 2022
# 136763   A851755  T'Challa   2/28/2022 11:25:00 AM           2022
# 136764   A851755  T'Challa   2/28/2022 11:25:00 AM           2022
#
#                                 Found Location    Intake Type  \
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
# 136764                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
# 136764           Normal         cat   Neutered Male         4 years
#
#                                 Breed         Color               Type
# 136760  Chihuahua Shorthair/Dachshund   Black/White          Stray Dog
# 136761                   Pit Bull Mix  White/Yellow          Stray Dog
# 136762                     Cane Corso    Blue Cream          Stray Dog
# 136763             Domestic Shorthair         Black  Public Assist Cat
# 136764             Domestic Shorthair         Black                NaN

# %%
cats = df_new.loc[(df_new['Animal Type'] == "Cat") | (df_new['Animal Type'] == "cat")]

# %%
cats.sort_values(by = 'Animal Type', ascending=False)
# Out:
#        Animal ID         Name                DateTime      MonthYear  \
# 136764   A851755     T'Challa   2/28/2022 11:25:00 AM           2022
# 90912    A676634       Kasami  04/12/2014 06:18:00 PM     April 2014
# 90881    A317744  Sofie Belle  08/26/2020 06:21:00 PM    August 2020
# 90882    A793787        Diana  04/29/2019 07:31:00 PM     April 2019
# 90884    A700592       Jessie  04/16/2015 02:13:00 PM     April 2015
# ...          ...          ...                     ...            ...
# 45167    A681163          NaN  06/13/2014 02:06:00 PM      June 2014
# 45171    A770308       Mowgli  01/06/2020 05:10:00 PM   January 2020
# 45175    A739482          NaN  12/03/2016 02:56:00 PM  December 2016
# 45179    A771741         *Meg  05/08/2018 11:22:00 AM       May 2018
# 68238    A769563          NaN  04/06/2018 02:34:00 PM     April 2018
#
#                                          Found Location      Intake Type  \
# 136764                                     Houston (TX)    Public Assist
# 90912                                       Austin (TX)  Owner Surrender
# 90881                      1700 E 4Th St in Austin (TX)    Public Assist
# 90882   Fiesta Street And Govalle Avenue in Austin (TX)            Stray
# 90884                                       Austin (TX)  Owner Surrender
# ...                                                 ...              ...
# 45167              5701 S Mopac Apt 1813 in Austin (TX)            Stray
# 45171                                       Austin (TX)  Owner Surrender
# 45175               2801 S Lakeline Blvd in Austin (TX)            Stray
# 45179               17305 Pearce Lane in Del Valle (TX)            Stray
# 68238                                       Austin (TX)            Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 136764           Normal         cat   Neutered Male         4 years
# 90912            Normal         Cat   Intact Female         4 years
# 90881            Normal         Cat   Spayed Female        17 years
# 90882            Normal         Cat   Intact Female         2 weeks
# 90884            Normal         Cat   Intact Female        3 months
# ...                 ...         ...             ...             ...
# 45167           Nursing         Cat     Intact Male         2 weeks
# 45171            Normal         Cat   Neutered Male          1 year
# 45175            Normal         Cat     Intact Male         3 years
# 45179            Normal         Cat   Intact Female         3 weeks
# 68238           Nursing         Cat     Intact Male          1 week
#
#                          Breed         Color                 Type
# 136764      Domestic Shorthair         Black                  NaN
# 90912   Domestic Shorthair Mix         Black  Owner Surrender Cat
# 90881   Domestic Shorthair Mix          Blue    Public Assist Cat
# 90882              Siamese Mix    Seal Point            Stray Cat
# 90884   Domestic Shorthair Mix    Lynx Point  Owner Surrender Cat
# ...                        ...           ...                  ...
# 45167   Domestic Shorthair Mix  Orange Tabby            Stray Cat
# 45171   Domestic Shorthair Mix   Brown Tabby  Owner Surrender Cat
# 45175   Domestic Shorthair Mix    Blue Tabby            Stray Cat
# 45179   Domestic Shorthair Mix  Torbie/White            Stray Cat
# 68238   Domestic Shorthair Mix    Gray/White            Stray Cat
#
# [51754 rows x 13 columns]

# %%
cats['Animal Type'].value_counts()
# Out:
# Cat    51753
# cat        1
# Name: Animal Type, dtype: int64

# %% [markdown]
# # Extra Credit: Find a .csv file online and experiment with it.

# %% [markdown]
# Head to [dataportals.org](https://dataportals.org) to find a .csv file.
